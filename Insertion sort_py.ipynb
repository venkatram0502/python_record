# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatram0502/python_record/blob/main/Insertion%20sort_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def insertion_sort(arr):
  for i in range(1, len(arr)):
    key = arr[i]
    j = i - 1
    while j >= 0 and arr[j] > key:
      arr[j + 1] = arr[j]
      j -= 1
    arr[j + 1] = key
# Example usage:
nums = [3, 2, 1, -1, -2, 6]
insertion_sort(nums)
print("Insertion sort result:", nums)
# Out:
# Insertion sort result: [-2, -1, 1, 2, 3, 6]
