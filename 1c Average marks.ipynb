# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatram0502/python_record/blob/main/1C%20Average%20marks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = input("Enter a number: ")
if number == number[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
for i in range(10):
    count = number.count(str(i))
    if count > 0:
        print(f"{i} appears {count} times")
# Out:
# Enter a number: 9100421576
# Not Palindrome
# 0 appears 2 times
# 1 appears 2 times
# 2 appears 1 times
# 4 appears 1 times
# 5 appears 1 times
# 6 appears 1 times
# 7 appears 1 times
# 9 appears 1 times
